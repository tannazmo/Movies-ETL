# %%
import pandas as pd
file_dir = 'data/'

# %%
#movies_metadata=pd.read_csv('data/movies_metadata.csv', low_memory=False)
kaggle_metadata = pd.read_csv(f"{file_dir}movies_metadata.csv", low_memory=False)
#ratings = pd.read_csv('data/ratings.csv')
ratings=pd.read_csv(f'{file_dir}ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview  ... release_date  \
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45461     0.0    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                           tagline                title  video  \
# 45461  Rising and falling between a man and woman               Subdue  False
# 45462                                         NaN  Century of Birthing  False
# 45463                      A deadly game of wits.             Betrayal  False
# 45464                                         NaN     Satan Triumphant  False
# 45465                                         NaN             Queerama  False
#
#       vote_average vote_count
# 45461          4.0        1.0
# 45462          9.0        3.0
# 45463          3.8        6.0
# 45464          0.0        0.0
# 45465          0.0        0.0
#
# [5 rows x 24 columns]

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
movies_metadata[20000:20005]
# Out:
#        adult                              belongs_to_collection  budget  \
# 20000  False  {'id': 409138, 'name': 'Yossi Collection', 'po...  500000
# 20001  False                                                NaN       0
# 20002  False                                                NaN       0
# 20003  False                                                NaN       0
# 20004  False                                                NaN       0
#
#                                                   genres  \
# 20000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 20001                [{'id': 99, 'name': 'Documentary'}]
# 20002                      [{'id': 18, 'name': 'Drama'}]
# 20003  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 20004                      [{'id': 18, 'name': 'Drama'}]
#
#                         homepage      id    imdb_id original_language  \
# 20000      http://yossifilm.com/  117629  tt1934269                he
# 20001                        NaN  288101  tt0869155                en
# 20002  http://joemaythemovie.com   76800  tt1550902                en
# 20003                        NaN  147590  tt0091935                cn
# 20004                        NaN  138357  tt0048517                fr
#
#                               original_title  \
# 20000                         הסיפור של יוסי
# 20001  Tout refleurit: Pedro Costa, cinéaste
# 20002              The Last Rites of Joe May
# 20003                                  殺妻二人組
# 20004                           The Prodigal
#
#                                                 overview  ... release_date  \
# 20000  The sequel to "Yossi and Jagger" finds charact...  ...   2012-05-16
# 20001  With this movie, Aurélien Gerbault invites us ...  ...   2006-07-10
# 20002  Now in his sixties, Joe is released from the h...  ...   2011-10-28
# 20003  Two men, Yun-Fat Chow and Kenny Bee, are both ...  ...   1986-09-24
# 20004  A wealthy young Hebrew traveling in Damascus r...  ...   1955-05-06
#
#         revenue runtime                            spoken_languages    status  \
# 20000  116207.0    84.0   [{'iso_639_1': 'he', 'name': 'עִבְרִית'}]  Released
# 20001       0.0    78.0   [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 20002       0.0   106.0    [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20003       0.0    92.0  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}]  Released
# 20004       0.0   112.0    [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        tagline                                      title  video vote_average  \
# 20000      NaN                                      Yossi  False          6.8
# 20001      NaN  All Blossoms Again: Pedro Costa, Director  False          0.0
# 20002      NaN                  The Last Rites of Joe May  False          6.1
# 20003      NaN               100 Ways to Murder Your Wife  False          4.0
# 20004      NaN                               The Prodigal  False          5.0
#
#       vote_count
# 20000       22.0
# 20001        0.0
# 20002        7.0
# 20003        1.0
# 20004        1.0
#
# [5 rows x 24 columns]

# %%
ratings[13000000:13000005]
# Out:
#           userId  movieId  rating   timestamp
# 13000000  134996    32587     3.0  1448423558
# 13000001  134996    33679     3.5  1378169508
# 13000002  134996    34405     4.0  1378170533
# 13000003  134996    36529     3.0  1398832177
# 13000004  134996    37729     2.5  1378169799

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 20298  False                   NaN      0
# 13232  False                   NaN      0
# 6876   False                   NaN      0
# 11767  False                   NaN      0
# 41132  False                   NaN      0
#
#                                                   genres homepage      id  \
# 20298  [{'id': 37, 'name': 'Western'}, {'id': 28, 'na...      NaN   71768
# 13232                      [{'id': 18, 'name': 'Drama'}]      NaN   51817
# 6876   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN   10729
# 11767  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN   18767
# 41132                                                 []      NaN  283792
#
#          imdb_id original_language                    original_title  \
# 20298  tt0050470                en        The Guns Of Fort Petticoat
# 13232  tt0326449                sr                    Zona Zamfirova
# 6876   tt0100449                en                      Quick Change
# 11767  tt0099812                cn                               火燒島
# 41132  tt0184939                el  Ο Θανάσης στη χώρα της σφαλιάρας
#
#                                                 overview  ... release_date  \
# 20298  Opposing his commanding officer's decision to ...  ...   1957-04-01
# 13232  Zona Zamfirova is set in the eastern Serbian c...  ...   2002-10-31
# 6876   With the aid of his girlfriend, Phyllis Potter...  ...   1990-07-13
# 11767  Someone in a prison run by a corrupt warden fa...  ...   1990-01-01
# 41132  The movie is about dictatorships in Greece – f...  ...   1976-07-25
#
#       revenue runtime                           spoken_languages    status  \
# 20298     0.0    82.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 13232     0.0   104.0    [{'iso_639_1': 'sr', 'name': 'Srpski'}]  Released
# 6876      0.0    89.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11767     0.0    95.0       [{'iso_639_1': 'zh', 'name': '普通话'}]  Released
# 41132     0.0    88.0  [{'iso_639_1': 'el', 'name': 'ελληνικά'}]  Released
#
#                                                  tagline  \
# 20298  GOOD WOMEN...BAD WOMEN...BRAWLING WOMEN...BRAV...
# 13232                                                NaN
# 6876   The bank robbery was easy. But getting out of ...
# 11767  When you're looking for the living dead you st...
# 41132                                                NaN
#
#                                   title  video vote_average vote_count
# 20298        The Guns Of Fort Petticoat  False          4.9       10.0
# 13232                     Zamfir's Zona  False          7.3        6.0
# 6876                       Quick Change  False          6.3       75.0
# 11767                    Island of Fire  False          5.9       26.0
# 41132  Ο Θανάσης στη χώρα της σφαλιάρας  False          0.0        0.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 4460154    45866    27660     4.0  1237474534
# 13917248  144616     1207     4.5  1148563602
# 986017     10068     1704     4.0  1111481462
# 8056924    83173      105     5.0  1110419757
# 18597352  193073     4901     3.0  1023060380
